# %% [markdown]
# # Linear and multi-linear regression #
#
# Name: Michael Dresser
#
# ## Linear Regression ##
# We can model the linear relationship between two variables by generating a regression line from the data. The regression line tells you how much of the variance in the dependent variable is explained by the independent variable. We want to find the line that best represents the relationship. For a data set X, Y, where X is the independent variable and Y is the dependent variable, we describe the regression line for X, Y as:
#
# $$\hat{y} = mx + b$$
#
# where
#
# $\hat{y}$ = predicted value of y,
# b = intercept,
# m = regression coefficient
#
# The value $\hat{y} - y$ is the residual. If $\hat{y} > y$, then the residual is -, and if $\hat{y} < y$, then the residual is +. The regression line minimizes the sum of the squared residuals. We can calculate $m$ and $b$ as
#
# $$m = r\frac{S_y}{S_x}$$
#
# $$b = \bar{y} - m\bar{x}$$
#
# Once we have the regression line, we can use it for prediction of unobserved values in the data.
#
# For example, in last week's lecture, you generated a linear regression between __Salary__ and __Wins__ to model how well does a team's salary explains the wins they achieve in a season. The plot looked something like this:

# %%
#Linear regression example
#Prediction from one variable
#Need to generate the data. Lahman
from pybaseball.lahman import *
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

sal = salaries()
sal2000 = sal.loc[sal['yearID'] >= 2000].copy()
sal2000.head()
teamSalaries = sal2000.groupby(['yearID', 'teamID'], as_index=False).agg({'salary':'sum'})
teamSalaries.head()

#get wins per season
t = teams()
teams2000 = t.loc[t['yearID'] >= 2000, ['yearID', 'teamID', 'W', 'L', 'attendance']]

#merge wins and salaries data
teamsWinsSalaries = pd.merge(teamSalaries, teams2000, on=['yearID', 'teamID'], how='inner')
teamsWinsSalaries.head()

from scipy import stats
m, b, rval, pval, stderr = stats.linregress(teamsWinsSalaries['salary'], teamsWinsSalaries['W'])
y = m * teamsWinsSalaries['salary'].copy() + b
x = teamsWinsSalaries['salary'].copy()

fig, ax = plt.subplots()
scatter = ax.scatter(x,teamsWinsSalaries['W'],marker='o',label="W vs. Salary")
line = ax.plot(x,y, color='red',label="W vs. Salary predicted")
ax.set_xlabel("Salary", fontsize=16)
ax.set_ylabel("Wins", fontsize=16)
plt.legend()

# %% [markdown]
# ## Multiple linear regression ##
# With multiple linear regression, we use multiple variables to predict a dependent variable. For example, instead of salary as the predictor of wins, we could use a team's salary, ERA, and OBP to predict wins. Each of these independent variables would be assigned a weight that determines how much that variable influences the outcome of the regression for one unit of change in the variable.
#
# The predicted value for the ith data point is described by:
#
# $$\hat{y_i} = B_0 + B_1x_{i1} + B_2{x_i2}+\cdots+e_i$$
#
# where $e_i$ is the error in the prediction.
#
# What is the predicted number of wins for a team given their team ERA and OBP for a season? Use data since 2010.

# %%
tMLR = t.loc[t['yearID']>= 2010, ['yearID', 'teamID', 'W', 'H', 'BB', 'HBP', 'SF', 'ERA', 'AB']]
tMLR.head()
tMLR['OBP'] = (tMLR['H'] + tMLR['BB'] + tMLR['HBP'])/(tMLR['AB'] + tMLR['BB'] + tMLR['HBP'] + tMLR['SF'])
tMLR.head()
# Out:
#       yearID teamID   W     H   BB   HBP    SF   ERA    AB       OBP
# 2625    2010    ARI  65  1366  589  39.0  41.0  4.81  5473  0.324650
# 2626    2010    ATL  91  1411  634  51.0  35.0  3.56  5463  0.338994
# 2627    2010    BAL  66  1440  424  54.0  45.0  4.59  5554  0.315616
# 2628    2010    BOS  89  1511  587  47.0  46.0  4.20  5646  0.339077
# 2629    2010    CHA  88  1467  467  79.0  38.0  4.09  5484  0.331740

# %% [markdown]
# In this exercise you'll fit a multiple linear regression model to the ERA, OBP, and Wins data.  PANDAS has a package called [statsmodels](http://www.statsmodels.org/stable/index.html).  We load it as follows.

# %%
#MLR from pandas
#you can also use statsmodels for linear regression
import statsmodels.api as sm 
# Collect the features in a 2D array 
X = tMLR[["ERA", "OBP"]]
# Add a constant to the array for the intercept
#You need a good reason if you don't have an intercept
X = sm.add_constant(X)

# The dependent variable is wins, put in an array 
y = tMLR["W"]

# Fit the ordinary least-squares (OLS) model 
model = sm.OLS(y, X).fit()

#How good is the fit?
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      W   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     330.3
# Date:                Wed, 06 Mar 2019   Prob (F-statistic):           3.82e-65
# Time:                        15:38:47   Log-Likelihood:                -649.01
# No. Observations:                 210   AIC:                             1304.
# Df Residuals:                     207   BIC:                             1314.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.1648     10.560     -0.205      0.838     -22.984      18.654
# ERA          -16.3740      0.811    -20.195      0.000     -17.972     -14.775
# OBP          464.0785     31.039     14.951      0.000     402.885     525.272
# ==============================================================================
# Omnibus:                        4.756   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                4.397
# Skew:                           0.340   Prob(JB):                        0.111
# Kurtosis:                       3.203   Cond. No.                         364.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Questions: #
# 1. Explore how different offensive stats, such as OBP, BA, Plate Appearances, and WAR predict a player's salary. Use a linear and a multi-linear approach.
# 2. Repeat question 1 for pitchers using valid pitching stats.
# 3. What do your results tell you about which stats are being valued more in a player's salary?
#
# Note: In pybaseball, there are functions that return the WAR stats for batting and pitching.
#
# More information about batting: <a href="https://github.com/jldbc/pybaseball/blob/master/docs/bwar_bat.md" target="_blank">Batting WAR docs</a>
#
# More information about pitching: <a href="https://github.com/jldbc/pybaseball/blob/master/docs/bwar_pitch.md" target="_blank">Pitching WAR docs</a>

# %%
from pybaseball import bwar_bat
from pybaseball import batting_stats

# get war stats from baseball reference 
data = bwar_bat()
data = data.loc[(data["pitcher"] != "Y")].copy()
data.head()
# Out:
#    name_common    mlb_ID  player_ID  year_ID team_ID  stint_ID lg_ID pitcher  \
# 9   Hank Aaron  110001.0  aaronha01     1954     MLN         1    NL       N
# 10  Hank Aaron  110001.0  aaronha01     1955     MLN         1    NL       N
# 11  Hank Aaron  110001.0  aaronha01     1956     MLN         1    NL       N
# 12  Hank Aaron  110001.0  aaronha01     1957     MLN         1    NL       N
# 13  Hank Aaron  110001.0  aaronha01     1958     MLN         1    NL       N
#
#       G     PA   salary  runs_above_avg  runs_above_avg_off  \
# 9   122  509.0   6000.0            -5.0                -4.0
# 10  153  665.0  10000.0            40.2                33.1
# 11  153  660.0  17500.0            47.4                32.5
# 12  151  675.0  22500.0            55.1                51.0
# 13  153  664.0  35000.0            47.7                39.6
#
#     runs_above_avg_def  WAR_rep   WAA   WAR
# 9                 -6.3     1.88 -0.61  1.27
# 10                 2.1     2.48  3.77  6.25
# 11                 8.1     2.55  4.63  7.18
# 12                -0.1     2.47  5.50  7.97
# 13                 2.5     2.48  4.84  7.32

# %%
data.loc[(data["year_ID"] >= 2010)].sort_values("salary").dropna()
# Out:
#                   name_common    mlb_ID  player_ID  year_ID team_ID  stint_ID  \
# 31792                Sam Fuld  453539.0   fuldsa01     2010     CHC         1
# 43189         Micah Hoffpauir  451687.0  hoffpmi01     2010     CHC         1
# 82088            Adam Rosales  489267.0  rosalad01     2018     CLE         1
# 5581           Gordon Beckham  493596.0  beckhgo01     2018     SEA         1
# 83701   Jarrod Saltalamacchia  457454.0  saltaja01     2018     DET         1
# 88034          Scott Sizemore  502003.0  sizemsc01     2010     DET         1
# 13032             Drew Butera  460077.0  buterdr01     2010     MIN         1
# 31017          Juan Francisco  464433.0  francju02     2010     CIN         1
# 56891              Donny Lucy  455113.0   lucydo01     2010     CHW         1
# 42224           Jason Heyward  518792.0  heywaja01     2010     ATL         1
# 90936          Nick Stavinoha  458036.0  stavini01     2010     STL         1
# 93590             Craig Tatum  461874.0  tatumcr01     2010     BAL         1
# 93686           Willy Taveras  430838.0  taverwi01     2010     WSN         1
# 13286             Eric Byrnes  291565.0  byrneer01     2010     SEA         1
# 94033            Ruben Tejada  514913.0  tejadru01     2010     NYM         1
# 59941              Joe Mather  458628.0  mathejo02     2010     STL         1
# 41686         Diory Hernandez  452671.0  hernadi01     2010     ATL         1
# 58675          Tommy Manzella  446373.0  manzeto01     2010     HOU         1
# 23565             Ian Desmond  435622.0  desmoia01     2010     WSN         1
# 19995             Allen Craig  501800.0  craigal01     2010     STL         1
# 64941            Juan Miranda  506673.0  miranju01     2010     NYY         1
# 31347            David Freese  501896.0  freesda01     2010     STL         1
# 45818          Austin Jackson  457706.0  jacksau01     2010     DET         1
# 78830           Nolan Reimold  460099.0  reimono01     2010     BAL         1
# 47036           Chris Johnson  453400.0  johnsch05     2010     HOU         1
# 18806           Brooks Conrad  462405.0  conrabr01     2010     ATL         1
# 101829           Matt Wieters  446308.0  wietema01     2010     BAL         1
# 92189             Drew Stubbs  453211.0  stubbdr01     2010     CIN         1
# 78290             John Raynor  489231.0  raynojo01     2010     PIT         1
# 61327              Mike McCoy  453454.0  mccoymi01     2010     TOR         1
# ...                       ...       ...        ...      ...     ...       ...
# 14175           Robinson Cano  429664.0   canoro01     2014     SEA         1
# 14177           Robinson Cano  429664.0   canoro01     2016     SEA         1
# 76928           Albert Pujols  405395.0  pujolal01     2015     LAA         1
# 29158          Prince Fielder  425902.0  fieldpr01     2016     TEX         1
# 29157          Prince Fielder  425902.0  fieldpr01     2015     TEX         1
# 29156          Prince Fielder  425902.0  fieldpr01     2014     TEX         1
# 14179           Robinson Cano  429664.0   canoro01     2018     SEA         1
# 14176           Robinson Cano  429664.0   canoro01     2015     SEA         1
# 14178           Robinson Cano  429664.0   canoro01     2017     SEA         1
# 76929           Albert Pujols  405395.0  pujolal01     2016     LAA         1
# 44280             Ryan Howard  429667.0  howarry01     2015     PHI         1
# 98549              Joey Votto  458015.0  vottojo01     2018     CIN         1
# 44281             Ryan Howard  429667.0  howarry01     2016     PHI         1
# 90790       Giancarlo Stanton  519317.0  stantmi03     2018     NYY         1
# 44279             Ryan Howard  429667.0  howarry01     2014     PHI         1
# 76930           Albert Pujols  405395.0  pujolal01     2017     LAA         1
# 100764           Vernon Wells  150484.0  wellsve01     2011     LAA         1
# 76931           Albert Pujols  405395.0  pujolal01     2018     LAA         1
# 15880         Yoenis Cespedes  493316.0  cespeyo01     2016     NYM         1
# 81201          Alex Rodriguez  121347.0  rodrial01     2013     NYY         1
# 13433          Miguel Cabrera  408234.0  cabremi01     2017     DET         1
# 13432          Miguel Cabrera  408234.0  cabremi01     2016     DET         1
# 42231           Jason Heyward  518792.0  heywaja01     2017     CHC         1
# 42232           Jason Heyward  518792.0  heywaja01     2018     CHC         1
# 81200          Alex Rodriguez  121347.0  rodrial01     2012     NYY         1
# 15882         Yoenis Cespedes  493316.0  cespeyo01     2018     NYM         1
# 13434          Miguel Cabrera  408234.0  cabremi01     2018     DET         1
# 81199          Alex Rodriguez  121347.0  rodrial01     2011     NYY         1
# 81198          Alex Rodriguez  121347.0  rodrial01     2010     NYY         1
# 96296              Mike Trout  545361.0  troutmi01     2018     LAA         1
#
#        lg_ID pitcher    G     PA      salary  runs_above_avg  \
# 31792     NL       N   19   31.0         1.0            -4.1
# 43189     NL       N   24   57.0         1.0            -5.8
# 82088     AL       N   13   21.0    100000.0            -0.7
# 5581      AL       N   22   50.0    100000.0            -0.7
# 83701     AL       N    5    8.0    100000.0            -2.7
# 88034     AL       N   48  163.0    400000.0           -12.8
# 13032     AL       N   49  155.0    400000.0            -4.0
# 31017     NL       N   36   59.0    400000.0            -1.5
# 56891     AL       N    7   18.0    400000.0             1.8
# 42224     NL       N  142  623.0    400000.0            45.1
# 90936     NL       N   79  126.0    400000.0            -4.8
# 93590     AL       N   43  126.0    400000.0            -1.7
# 93686     NL       N   27   37.0    400000.0            -3.7
# 13286     AL       N   15   38.0    400000.0            -4.5
# 94033     NL       N   78  255.0    400000.0            -9.4
# 59941     NL       N   36   64.0    400000.0            -5.7
# 41686     NL       N   20   10.0    400000.0            -0.8
# 58675     NL       N   83  282.0    400000.0           -19.9
# 23565     NL       N  154  574.0    400000.0            -5.0
# 19995     NL       N   44  124.0    400000.0            -2.3
# 64941     AL       N   33   71.0    400000.0            -1.6
# 31347     NL       N   70  270.0    400000.0            -0.8
# 45818     AL       N  151  675.0    400000.0            25.0
# 78830     AL       N   39  131.0    400000.0            -7.2
# 47036     NL       N   94  362.0    400000.0            -6.7
# 18806     NL       N  103  177.0    400000.0            -1.3
# 101829    AL       N  130  502.0    400000.0             6.5
# 92189     NL       N  150  583.0    400000.0            12.9
# 78290     NL       N   11   11.0    400000.0            -0.8
# 61327     AL       N   46   90.0    400700.0            -3.1
# ...      ...     ...  ...    ...         ...             ...
# 14175     AL       N  157  665.0  24000000.0            35.0
# 14177     AL       N  161  715.0  24000000.0            46.9
# 76928     AL       N  157  661.0  24000000.0             5.3
# 29158     AL       N   89  370.0  24000000.0           -25.8
# 29157     AL       N  158  693.0  24000000.0            -6.1
# 29156     AL       N   42  178.0  24000000.0            -8.2
# 14179     AL       N   80  348.0  24000000.0            19.3
# 14176     AL       N  156  674.0  24000000.0             8.4
# 14178     AL       N  150  648.0  24000000.0            10.8
# 76929     AL       N  152  650.0  25000000.0           -10.6
# 44280     NL       N  129  503.0  25000000.0           -24.6
# 98549     NL       N  145  623.0  25000000.0            16.4
# 44281     NL       N  112  362.0  25000000.0           -25.3
# 90790     AL       N  158  705.0  25000000.0            14.1
# 44279     NL       N  153  648.0  25000000.0           -25.8
# 76930     AL       N  149  636.0  26000000.0           -39.1
# 100764    AL       N  131  529.0  26187500.0           -23.6
# 76931     AL       N  117  498.0  27000000.0           -13.4
# 15880     NL       N  132  543.0  27500000.0            15.3
# 81201     AL       N   44  181.0  28000000.0            -3.3
# 13433     AL       N  130  529.0  28000000.0           -26.3
# 13432     AL       N  158  679.0  28000000.0            22.2
# 42231     NL       N  126  481.0  28166667.0             8.3
# 42232     NL       N  127  489.0  28166667.0             2.2
# 81200     AL       N  122  529.0  29000000.0             3.5
# 15882     NL       N   38  157.0  29000000.0             4.5
# 13434     AL       N   38  157.0  30000000.0            -0.4
# 81199     AL       N   99  428.0  32000000.0            23.8
# 81198     AL       N  137  595.0  33000000.0            18.6
# 96296     AL       N  140  608.0  34083000.0            79.7
#
#         runs_above_avg_off  runs_above_avg_def  WAR_rep   WAA    WAR
# 31792                 -4.1                -0.1     0.09 -0.45  -0.36
# 43189                 -5.8                -0.8     0.17 -0.64  -0.47
# 82088                 -0.7                -0.1     0.07 -0.06   0.01
# 5581                  -2.7                 2.4     0.16 -0.05   0.11
# 83701                 -1.7                -1.1     0.03 -0.28  -0.25
# 88034                 -5.8                -6.0     0.60 -1.30  -0.70
# 13032                 -7.0                 5.9     0.56 -0.39   0.17
# 31017                 -1.5                 0.2     0.17 -0.16   0.01
# 56891                  2.8                -0.7     0.06  0.18   0.24
# 42224                 30.1                 9.9     1.82  4.60   6.42
# 90936                 -5.8                -0.1     0.38 -0.54  -0.16
# 93590                 -1.7                 2.3     0.46 -0.16   0.30
# 93686                 -4.7                 0.4     0.11 -0.41  -0.30
# 13286                 -4.5                -0.8     0.14 -0.47  -0.33
# 94033                 -7.4                 0.8     0.77 -1.06  -0.29
# 59941                 -5.7                -0.6     0.19 -0.61  -0.42
# 41686                 -0.8                 0.1     0.03 -0.08  -0.05
# 58675                -15.9                 0.0     0.85 -2.19  -1.34
# 23565                  2.0                 0.2     1.73 -0.64   1.09
# 19995                 -3.3                -0.5     0.37 -0.28   0.09
# 64941                 -2.6                -1.1     0.26 -0.16   0.10
# 31347                  4.2                -3.8     0.81 -0.13   0.68
# 45818                 12.0                16.5     2.32  2.75   5.07
# 78830                 -8.2                -1.1     0.48 -0.74  -0.26
# 47036                  9.3               -14.2     1.08 -0.77   0.31
# 18806                  5.8                -6.1     0.53 -0.17   0.36
# 101829                -0.5                14.9     1.83  0.78   2.61
# 92189                 13.9                 2.3     1.76  1.23   2.99
# 78290                 -0.8                 0.0     0.04 -0.09  -0.05
# 61327                 -6.1                 3.2     0.32 -0.31   0.01
# ...                    ...                 ...      ...   ...    ...
# 14175                 35.0                 3.4     2.32  4.03   6.35
# 14177                 35.9                15.0     2.39  4.94   7.33
# 76928                  1.3                -6.9     2.31  0.71   3.02
# 29158                -24.8                -8.9     1.30 -2.67  -1.37
# 29157                 -1.1               -20.0     2.35 -0.51   1.84
# 29156                 -6.2                -4.4     0.62 -0.84  -0.22
# 14179                 18.3                 2.0     1.16  2.08   3.24
# 14176                 17.4                -5.3     2.32  1.03   3.35
# 14178                 10.8                 4.0     2.21  1.15   3.36
# 76929                 -6.6               -16.8     2.26 -0.97   1.29
# 44280                -15.6               -15.7     1.59 -2.81  -1.22
# 98549                  7.4                 1.5     1.94  1.51   3.45
# 44281                -16.3               -14.3     1.13 -2.73  -1.60
# 90790                  9.1                -5.7     2.29  1.72   4.01
# 44279                -15.8               -18.2     2.05 -3.21  -1.16
# 76930                -38.1               -14.5     2.19 -3.94  -1.75
# 100764               -11.6               -17.2     1.91 -2.45  -0.54
# 76931                -15.4                -6.2     1.70 -1.19   0.51
# 15880                 18.3                -5.1     1.71  1.43   3.14
# 81201                 -0.3                -3.9     0.61 -0.29   0.32
# 13433                -18.3               -15.7     1.84 -2.61  -0.77
# 13432                 28.2               -14.8     2.35  2.39   4.74
# 42231                 -9.7                13.9     1.51  0.78   2.29
# 42232                 -3.8                 2.1     1.56  0.05   1.61
# 81200                  5.5                -3.8     1.89  0.34   2.23
# 15882                  4.5                -1.4     0.50  0.42   0.92
# 13434                  1.6                -4.2     0.54  0.02   0.56
# 81199                  9.8                14.9     1.50  2.52   4.02
# 81198                 15.6                 4.5     2.11  2.04   4.15
# 96296                 71.7                 9.7     2.03  8.12  10.15
#
# [3762 rows x 17 columns]

# %%
b = batting()

# %%
b['OBP'] = (b['H'] + b['BB'] + b['HBP'])/(b['AB'] + b['BB'] + b['HBP'] + b['SF'])
b['BA'] = b['H'] / b['AB']
b = b.loc[(b["yearID"] >= 2010)].copy()

# %%
battingMLR = pd.merge(b, data, left_on=["playerID", "yearID"], right_on=["player_ID", "year_ID"]).dropna()

# %%
battingMLR
# Out:
#        playerID  yearID  stint teamID lgID  G_x   AB    R    H  2B  ...    \
# 0     abreubo01    2010      1    LAA   AL  154  573   88  146  41  ...
# 1     abreuto01    2010      1    ARI   NL   81  193   16   45  11  ...
# 5     alonsyo01    2010      1    CIN   NL   22   29    2    6   2  ...
# 6     alvarpe01    2010      1    PIT   NL   95  347   42   89  21  ...
# 8     anderga01    2010      1    LAN   NL   80  155    8   28   6  ...
# 11    andruel01    2010      1    TEX   AL  148  588   88  156  15  ...
# 13    ankieri01    2010      1    KCA   AL   27   92   14   24   7  ...
# 15    ankieri01    2010      2    ATL   NL   47  119   17   25   6  ...
# 18    ariasjo01    2010      1    TEX   AL   50   98   18   27   5  ...
# 20    ariasjo01    2010      2    NYN   NL   22   30    5    6   1  ...
# 21    atkinga01    2010      1    BAL   AL   44  140    5   30   7  ...
# 22    ausmubr01    2010      1    LAN   NL   21   63    4   14   2  ...
# 23    avilaal01    2010      1    DET   AL  104  294   28   67  12  ...
# 24    avilemi01    2010      1    KCA   AL  110  424   63  129  16  ...
# 25    aybarer01    2010      1    LAA   AL  138  534   69  135  18  ...
# 26    aybarwi01    2010      1    TBA   AL  100  270   22   62  13  ...
# 27    bakerje03    2010      1    CHN   NL   79  206   29   56  13  ...
# 28    bakerjo01    2010      1    FLO   NL   23   78    7   17   3  ...
# 31    barajro01    2010      1    NYN   NL   74  249   30   56  11  ...
# 33    barajro01    2010      2    LAN   NL   25   64    9   19   3  ...
# 34    bardebr01    2010      1    FLO   NL   35   28    2    5   0  ...
# 36    barmecl01    2010      1    COL   NL  133  387   43   91  21  ...
# 38    bartlja01    2010      1    TBA   AL  135  468   71  119  27  ...
# 39    bartoda02    2010      1    OAK   AL  159  556   79  152  33  ...
# 40    bautijo02    2010      1    TOR   AL  161  569  109  148  35  ...
# 42      bayja01    2010      1    NYN   NL   95  348   48   90  20  ...
# 43    beckhgo01    2010      1    CHA   AL  131  444   58  112  25  ...
# 44    belliro01    2010      1    LAN   NL   82  162   24   35  10  ...
# 46    beltrad01    2010      1    BOS   AL  154  589   84  189  49  ...
# 47    beltrca01    2010      1    NYN   NL   64  220   21   56  11  ...
# ...         ...     ...    ...    ...  ...  ...  ...  ...  ...  ..  ...
# 5616  troutmi01    2016      1    LAA   AL  159  549  123  173  32  ...
# 5617  trumbma01    2016      1    BAL   AL  159  613   94  157  27  ...
# 5618  tuckepr01    2016      1    HOU   AL   48  134   11   22   8  ...
# 5620  tulowtr01    2016      1    TOR   AL  131  492   54  125  21  ...
# 5621  turneju01    2016      1    LAN   NL  151  556   79  153  34  ...
# 5624  uptonbj01    2016      1    SDN   NL   92  344   46   88  11  ...
# 5626  uptonbj01    2016      2    TOR   AL   57  148   18   29   4  ...
# 5627  uptonju01    2016      1    DET   AL  153  570   81  140  28  ...
# 5628  uribeju01    2016      1    CLE   AL   73  238   19   49   9  ...
# 5629  utleych01    2016      1    LAN   NL  138  512   79  129  26  ...
# 5631  valbulu01    2016      1    HOU   AL   90  292   38   76  17  ...
# 5632  valenda01    2016      1    OAK   AL  130  471   72  135  22  ...
# 5633  vanslsc01    2016      1    LAN   NL   52  102   10   23   6  ...
# 5635  vazquch01    2016      1    BOS   AL   57  172   21   39   9  ...
# 5637  villajo01    2016      1    MIL   NL  156  589   92  168  38  ...
# 5639   vogtst01    2016      1    OAK   AL  137  490   54  123  30  ...
# 5640  vottojo01    2016      1    CIN   NL  158  556  101  181  34  ...
# 5642  walkene01    2016      1    NYN   NL  113  412   57  116   9  ...
# 5643  wallabr01    2016      1    SDN   NL  119  217   19   41  10  ...
# 5644  walshco02    2016      1    MIL   NL   38   47    4    4   1  ...
# 5649  werthja01    2016      1    WAS   NL  143  525   84  128  28  ...
# 5650  whitety01    2016      1    HOU   AL   86  249   24   54  16  ...
# 5651  wietema01    2016      1    BAL   AL  124  423   48  103  17  ...
# 5662  wolteto01    2016      1    COL   NL   71  205   27   53  15  ...
# 5663   wongko01    2016      1    SLN   NL  121  313   39   75   7  ...
# 5665  wrighda03    2016      1    NYN   NL   37  137   18   31   8  ...
# 5666  yelicch01    2016      1    MIA   NL  155  578   78  172  38  ...
# 5668  youngch04    2016      1    BOS   AL   76  203   29   56  18  ...
# 5670  zimmery01    2016      1    WAS   NL  115  427   60   93  18  ...
# 5671  zobribe01    2016      1    CHN   NL  147  523   94  142  31  ...
#
#       pitcher  G_y     PA      salary  runs_above_avg  runs_above_avg_off  \
# 0           N  154  667.0   9000000.0            -6.2                 5.8
# 1           N   81  201.0    407000.0           -17.4               -15.4
# 5           N   22   29.0    500000.0            -1.1                -3.1
# 6           N   95  386.0    500000.0            -5.2                 4.8
# 8           N   80  163.0    550000.0           -14.1               -15.1
# 11          N  148  674.0    418420.0           -11.9                -4.9
# 13          N   27  101.0   2750000.0            -0.9                 2.2
# 15          N   27  101.0   2750000.0            -0.9                 2.2
# 18          N   50  101.0    402000.0            -7.3                -4.3
# 20          N   50  101.0    402000.0            -7.3                -4.3
# 21          N   44  152.0   4000000.0           -17.8               -12.8
# 22          N   21   71.0    850000.0            -3.1                -2.1
# 23          N  104  333.0    404900.0           -11.6                -4.6
# 24          N  110  448.0    429000.0            -1.9                 6.1
# 25          N  138  589.0   2050000.0            -0.8                -4.8
# 26          N  100  309.0   1350000.0           -10.7               -10.7
# 27          N   79  224.0    975000.0            -0.8                -0.8
# 28          N   23   88.0    415000.0            -4.6                -3.6
# 31          N   74  267.0    500000.0            -6.2                -4.2
# 33          N   74  267.0    500000.0            -6.2                -4.2
# 34          N   35   32.0    415000.0            -2.9                -2.9
# 36          N  133  432.0   3325000.0            -1.0               -14.0
# 38          N  135  532.0   4000000.0             4.7                 5.7
# 39          N  159  686.0    410000.0            27.9                 9.9
# 40          N  161  683.0   2400000.0            42.6                45.6
# 42          N   95  401.0   8625000.0             6.0                 3.0
# 43          N  131  498.0    445000.0           -11.7                -4.7
# 44          N   82  185.0    825000.0            -8.3                -6.3
# 46          N  154  641.0   9000000.0            51.1                32.1
# 47          N   64  255.0  19401569.0            -0.5                 4.5
# ...       ...  ...    ...         ...             ...                 ...
# 5616        N  159  681.0  16083000.0            79.7                73.7
# 5617        N  159  667.0   9150000.0            -5.7                 5.4
# 5618        N   48  144.0    515000.0           -15.7               -11.7
# 5620        N  131  544.0  20000000.0            12.9                 2.9
# 5621        N  151  622.0   5100000.0            28.6                21.6
# 5624        N   57  165.0  15450000.0            -9.5               -11.5
# 5626        N   57  165.0  15450000.0            -9.5               -11.5
# 5627        N  153  626.0  22125000.0            -4.4                -4.4
# 5628        N   73  259.0   4000000.0           -13.3               -14.3
# 5629        N  138  565.0   7000000.0             2.0                 5.0
# 5631        N   90  342.0   6125000.0            13.4                12.4
# 5632        N  130  517.0   3150000.0            -7.1                10.9
# 5633        N   52  113.0   1225000.0            -5.1                -8.1
# 5635        N   57  184.0    513000.0            -9.2                -8.2
# 5637        N  156  679.0    512900.0            19.6                19.6
# 5639        N  137  532.0    527500.0             0.8                 1.8
# 5640        N  158  677.0  20000000.0            20.6                34.6
# 5642        N  113  458.0  10550000.0            12.4                12.4
# 5643        N  119  256.0   1000000.0           -13.4                -8.4
# 5644        N   38   63.0    507500.0            -6.0                -5.0
# 5649        N  143  606.0  21000000.0           -14.7                -6.7
# 5650        N   85  276.0    507500.0            -9.5               -10.5
# 5651        N  124  464.0  15800000.0             1.7                -1.3
# 5662        N   71  230.0    507500.0             3.4                 1.4
# 5663        N  121  361.0   1250000.0             4.6                 0.6
# 5665        N   37  164.0  20000000.0            -5.6                 2.4
# 5666        N  155  659.0   1000000.0            34.1                28.1
# 5668        N   76  227.0   6500000.0             1.1                 3.1
# 5670        N  115  467.0  14000000.0           -24.3               -22.3
# 5671        N  147  631.0  10500000.0            18.7                21.7
#
#       runs_above_avg_def  WAR_rep   WAA    WAR
# 0                  -18.8     2.38 -0.53   1.85
# 1                   -0.5     0.60 -1.90  -1.30
# 5                    1.8     0.09 -0.13  -0.04
# 6                   -8.1     1.17 -0.62   0.55
# 8                   -0.3     0.49 -1.55  -1.06
# 11                   0.9     2.27 -1.12   1.15
# 13                  -2.4     0.37 -0.07   0.30
# 15                  -2.4     0.37 -0.07   0.30
# 18                  -2.9     0.37 -0.75  -0.38
# 20                  -2.9     0.37 -0.75  -0.38
# 21                  -7.5     0.55 -1.86  -1.31
# 22                   0.2     0.22 -0.34  -0.12
# 23                  -1.4     1.21 -1.15   0.06
# 24                  -5.0     1.64 -0.12   1.52
# 25                  11.1     2.13  0.03   2.16
# 26                  -6.6     1.13 -1.07   0.06
# 27                   0.9     0.67 -0.13   0.54
# 28                   0.3     0.26 -0.51  -0.25
# 31                   2.5     0.80 -0.70   0.10
# 33                   2.5     0.80 -0.70   0.10
# 34                   0.6     0.10 -0.32  -0.22
# 36                  17.7     1.30 -0.20   1.10
# 38                   5.5     1.95  0.59   2.54
# 39                   9.8     2.45  3.06   5.51
# 40                  -6.9     2.48  4.47   6.95
# 42                  -0.6     1.21  0.56   1.77
# 43                  -4.0     1.82 -1.14   0.68
# 44                  -1.7     0.56 -0.93  -0.37
# 46                  22.1     2.36  5.43   7.79
# 47                  -3.6     0.77 -0.10   0.67
# ...                  ...      ...   ...    ...
# 5616                 8.7     2.36  8.11  10.47
# 5617               -20.5     2.33 -0.46   1.87
# 5618                -7.0     0.50 -1.62  -1.12
# 5620                16.7     1.90  1.45   3.35
# 5621                 9.8     1.96  2.78   4.74
# 5624                 0.6     0.58 -0.98  -0.40
# 5626                 0.6     0.58 -0.98  -0.40
# 5627                -5.7     2.19 -0.34   1.85
# 5628                 2.2     0.90 -1.35  -0.45
# 5629                 0.5     1.78  0.07   1.85
# 5631                 2.2     1.20  1.44   2.64
# 5632               -19.6     1.81 -0.63   1.18
# 5633                 1.4     0.35 -0.57  -0.22
# 5635                 2.2     0.64 -0.93  -0.29
# 5637                 7.1     2.05  1.84   3.89
# 5639                 4.4     1.86  0.18   2.04
# 5640               -22.3     2.08  1.92   4.00
# 5642                 3.0     1.44  1.16   2.60
# 5643                -5.5     0.80 -1.46  -0.66
# 5644                -0.9     0.19 -0.65  -0.46
# 5649               -13.7     1.88 -1.68   0.20
# 5650                -3.6     0.95 -0.94   0.01
# 5651                10.3     1.63  0.26   1.89
# 5662                 6.2     0.72  0.30   1.02
# 5663                 6.0     1.13  0.38   1.51
# 5665                -7.2     0.49 -0.61  -0.12
# 5666                 2.1     2.04  3.33   5.37
# 5668                -4.5     0.79  0.15   0.94
# 5670                -8.1     1.48 -2.68  -1.20
# 5671                -1.8     1.93  1.75   3.68
#
# [3255 rows x 41 columns]

# %%
X = battingMLR[["OBP"]]
X = sm.add_constant(X)

y = battingMLR["salary"]

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 salary   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     243.0
# Date:                Wed, 06 Mar 2019   Prob (F-statistic):           6.85e-53
# Time:                        16:13:59   Log-Likelihood:                -54877.
# No. Observations:                3255   AIC:                         1.098e+05
# Df Residuals:                    3253   BIC:                         1.098e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.892e+06   4.54e+05     -6.368      0.000   -3.78e+06      -2e+06
# OBP          2.27e+07   1.46e+06     15.588      0.000    1.98e+07    2.56e+07
# ==============================================================================
# Omnibus:                     1106.157   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3200.144
# Skew:                           1.795   Prob(JB):                         0.00
# Kurtosis:                       6.272   Cond. No.                         17.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.scatter(battingMLR["OBP"], battingMLR["salary"])
