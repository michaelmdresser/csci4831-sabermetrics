# %%
from pybaseball import batting_stats

# %%
b = batting_stats(2016)

# %%
from pybaseball import playerid_lookup, playerid_reverse_lookup
import pandas as pd

# %%
playerid_lookup("mercer", "jordy")
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0    mercer      jordy     474568  mercj002  mercejo03           6547
#
#    mlb_played_first  mlb_played_last
# 0            2012.0           2019.0

# %%
playerid_lookup("gregorius", "didi")
# Out:
# Gathering player lookup table. This may take a moment.
#    name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0  gregorius       didi     544369  gregd001  gregodi01           6012
#
#    mlb_played_first  mlb_played_last
# 0            2012.0           2018.0

# %%
pd.set_option('display.max_columns', 300)

# %%
players = ["Jordy Mercer", "Danny Espinosa", 
           "Adeiny Hechavarria", "Didi Gregorius", 
           "Jose Iglesias", "Freddy Galvis"]
b.loc[(b["Name"].isin(players))]
# Out:
#      Season                Name       Team   Age      G     AB     PA      H  \
# 268  2016.0      Didi Gregorius    Yankees  26.0  153.0  562.0  597.0  155.0
# 428  2016.0       Freddy Galvis   Phillies  26.0  158.0  584.0  624.0  141.0
# 432  2016.0       Jose Iglesias     Tigers  26.0  137.0  467.0  513.0  119.0
# 345  2016.0        Jordy Mercer    Pirates  29.0  149.0  519.0  584.0  133.0
# 392  2016.0      Danny Espinosa  Nationals  29.0  157.0  516.0  601.0  108.0
# 533  2016.0  Adeiny Hechavarria    Marlins  27.0  155.0  508.0  547.0  120.0
#
#         1B    2B   3B    HR     R   RBI    BB   IBB     SO   HBP   SF   SH  \
# 268  101.0  32.0  2.0  20.0  68.0  70.0  19.0   2.0   82.0   6.0  5.0  5.0
# 428   92.0  26.0  3.0  20.0  61.0  67.0  25.0   6.0  136.0   3.0  4.0  8.0
# 432   89.0  26.0  0.0   4.0  57.0  32.0  28.0   1.0   50.0   8.0  3.0  7.0
# 345   97.0  22.0  3.0  11.0  66.0  59.0  51.0   8.0   83.0   5.0  2.0  7.0
# ...

# %% [markdown]
# best OBP, 2nd best OPS, 2nd best BABIP, 2nd best wOBA, 2nd best wRC, 2nd best wRC+, 2nd lowest SwStr%, 2nd best Contact%

# %%
from pybaseball.lahman import salaries

# %%
s = salaries()

# %%
s
# Out:
#        yearID teamID lgID   playerID    salary
# 0        1985    ATL   NL  barkele01    870000
# 1        1985    ATL   NL  bedrost01    550000
# 2        1985    ATL   NL  benedbr01    545000
# 3        1985    ATL   NL   campri01    633333
# 4        1985    ATL   NL  ceronri01    625000
# 5        1985    ATL   NL  chambch01    800000
# 6        1985    ATL   NL  dedmoje01    150000
# 7        1985    ATL   NL  forstte01    483333
# 8        1985    ATL   NL  garbege01    772000
# 9        1985    ATL   NL  harpete01    250000
# 10       1985    ATL   NL  hornebo01   1500000
# 11       1985    ATL   NL  hubbagl01    455000
# 12       1985    ATL   NL  mahleri01    407500
# 13       1985    ATL   NL  mcmurcr01    275000
# 14       1985    ATL   NL  mumphje01    775000
# 15       1985    ATL   NL  murphda05   1625000
# 16       1985    ATL   NL  oberkke01    616667
# 17       1985    ATL   NL  perezpa01    450000
# 18       1985    ATL   NL  perryge01    120000
# ...

# %%
s.loc[(s["yearID"] == 2016) & ((s["playerID"] == "mercejo03") | (s["playerID"] == "gregodi01"))]
# Out:
#        yearID teamID lgID   playerID   salary
# 26100    2016    NYY   AL  gregodi01  2425000
# 26196    2016    PIT   NL  mercejo03  2075000

# %%
2075000/2425000
# Out:
# 0.8556701030927835
